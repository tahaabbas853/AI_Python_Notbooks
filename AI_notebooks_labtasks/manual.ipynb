# %% [markdown]
# list

# %%
L1 = ["The Godfather", 1972, 9.2]
L1.extend(["Drama",3])
print(L1)
# Out:
# ['The Godfather', 1972, 9.2, 'Drama', 3]

# %% [markdown]
# array

# %%
b = np.array([ [1,2],
               [3,4],
               [5,6] ])

print(b)
print(b.size)
print(b.ndim)
print(b.shape)

# %%
c = np.array([ 1,12,3,44,5,6,67,8])

d = c.reshape(4,2)

print("Array c : ", c)
print("Array d : ", d)
print("c.shape : ", c.shape)
print("d.shape : ", d.shape)

# %% [markdown]
# element wise

# %%
A = np.array([2,3])
B = np.array([4,5])
F = A* B
F

# %% [markdown]
# matrix

# %%
A = np.array([[2,3]])
B = np.array([[4],[5]])
G = np.dot(A,B)
G

# %% [markdown]
# Boardcast

# %%
A = np.array([2,6,8,7,3])
H = A + 4
H

# %% [markdown]
# linespace

# %%
np.linspace(-2,2,num=5)

# %% [markdown]
# unique values in data

# %%
classes = data.target
#getting unique classes
unique_classes = np.unique(classes)

print(unique_classes)
print("Number of unique classes:", len(unique_classes))

# %% [markdown]
# shuffle

# %%
dataframe , target_val = shuffle(dataframe,target_val)

# %% [markdown]
# datafram to drop specific column

# %%
dataframe_drop = dataframe[dataframe['species'] != 'virginica']

# %% [markdown]
# map

# %%
sex_map = {'male': 0, 'female': 1}
embarked_map = {'S': 0, 'C': 1, 'Q': 2}
train_df['sex'] = train_df['sex'].map(sex_map)
train_df['embarked'] = train_df['embarked'].map(embarked_map)

# %% [markdown]
# min max scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns = ['Income', 'Card Debt','Other Debt','DebtIncomeRatio']
# Scale the features
data[columns] = scaler.fit_transform(data[columns])

# %% [markdown]
# plot

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
plt.plot(x,y)

# %%
a = np.random.random(100)
b = np.random.random(100)
plt.scatter(a,b)
plt.show()

# %%
plt.hist(a,bins=30)
plt.show()

# %%
# Generate data for the first line
x1 = np.linspace(0, 10, 20)
y1 = np.sin(x1)

# Generate data for the second line
x2 = np.linspace(0, 10, 20)
y2 = np.cos(x2)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the first line with a square marker
ax.plot(x1, y1, '-s', label='sin')

# Plot the second line with a diamond marker
ax.plot(x2, y2, '-D', label='cos')



# Add a legend to the plot
ax.legend()

# Set the title and labels
ax.set_title("Sine and Cosine")
ax.set_xlabel("x")
ax.set_ylabel("y")

# Show the plot
plt.show()

# %%
#make sub plots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs = axs.flatten()
for i in range(len(data.feature_names)):
    axs[i].hist(data.data[:, i], bins=10, color='b')
    axs[i].set_title(data.feature_names[i])
plt.show()

# %% [markdown]
# read/write file

# %%
import pandas as pd
path = "Auto85.csv"
data = pd.read_csv(path, header = None) #assumes data has header

data.head(5) 
headers = ["symboling","normalized-losses","make","fuel-type", 
           "aspiration", "num-of-doors", "body-style", "drive-wheels",
           "engine-location", "wheel-base", "length", "width", "height", 
           "curb-weight", "engine-type", "num-of-cylinders", "engine-size", 
           "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", 
           "peak-rpm", "city-mpg", "highway-mpg", "Price"]
data.columns = headers
data.head()
data["Price"]
data["Price"].replace("?", np.nan, inplace = True)
data["Price"] = pd.to_numeric(data["Price"])

# %% [markdown]
# graphs

# %%
import networkx as nx
# Create an empty graph
G = nx.Graph()
# Adding nodes manually
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)

G.add_nodes_from([5,6])

# Adding an edge
G.add_edge(1,2)
G.add_edge(1,3)
G.add_edge(3,1)
G.add_edge(2,4)
G.add_edge(4,1)
G.add_edge(4,5)
G.add_edge(5,6)
# Drawing graph
nx.draw(G)

# %%
# Adding edges from a list
G.add_edges_from ([(1,4), (2,5)])
# Drawing graph
nx.draw(G)

# %%
# Drawing options
options = {
    "font_size": 10,
    "node_size": 500,
    "node_color": "white",
    "edgecolors": "blue",
    "linewidths":4,
    "width": 4,
}
# Drawing with options
nx.draw_networkx(G, **options)

# %%
# Writing graph to a text file
nx.write_edgelist(G,"graph.txt")

# %% [markdown]
# graph from file

# %%
import pandas as pd
# Read data from csv file as data fram
df = pd.read_csv('SimpleGraph.csv')
# Creating an empty graph and then assigning data frame
G = nx.from_pandas_edgelist(df)
# Print nodes
print(G.nodes)
# Print edges
print(G.edges)
# Print number of nodes
print(G.number_of_nodes())
# Print number of edges
print(G.number_of_edges())
# Draw graph with labels
nx.draw(G, with_labels=True)
# Out:
# [1, 2, 3, 5, 4]
# [(1, 2), (1, 3), (1, 5), (2, 4), (3, 5), (5, 4)]
# 5
# 6

# %%
# View node 1
G[1]
#Degree of node 1
G.degree[1]
# Degrees of node 1 and 3
G.degree([1,3])
# Out:
# DegreeView({1: 3, 3: 2})

# %% [markdown]
# Agents

# %%
import os

class fire_alarm:
    def __init__(self):
        self.state = "normal"
    
    def set_alarm(self,temp,smoke):
        if smoke:
            if temp < 50 :
                print("smoke detected with normal temperature ")
                self.state = "Smoked with normal temperature"
                self.sprinkle_sys()
            elif temp > 50 or temp < 0:
                print("Smoke and temperature is greater than 50")
                self.state = "smoke and High Temp "
                self.sound_alarm()
                self.call_fire_dept()
                self.sprinkle_sys()
            else:
                print("Temp Sensor is not working")
                self.state = "Smoked and temp sensor not working"
                self.sprinkle_sys()

        elif smoke == False:
            if temp < 50:
                print("smoke not detected with normal temperature ")
                self.state = "not Smoked with normal temperature"
                
            elif temp > 50 or temp < 0:
                print("not Smoke and temperature is greater than 50")
                self.state = "not smoke and High Temp "
                self.sound_alarm()
                self.call_fire_dept()
                self.sprinkle_sys()
            else:
                print("Temp Sensor is not working")
                self.state = "not Smoked and temp sensor not working"
        else:
            print("Smoke Sensor is not working")
            self.state = "Smoke sensor not working"

    def sound_alarm(self):
            print("ALARAM SOUND ON.......\n")
            beep = lambda x: os.system("echo -n '\a';sleep 0.2;" * x)
            beep(3)
            print('\n')

    def sprinkle_sys(self):
            print("SPRINLE SYSTEM ACTIVATED..................")

    def call_fire_dept(self):
        print("CALLING THE FIRE DEPT...........................")

    def __str__(self):
        return f" state {self.state}"

fire_alarm = fire_alarm()

temperature = int(input("ENTER THE TEMPERATUR OF ENVIRONMENT "))
Smoke = input("ENTER THE SMOKE (True or False) ")

print(f"temperatur -> {temperature} Smoke -> {Smoke} ")

fire_alarm.set_alarm(temperature,Smoke)
print(fire_alarm)
# Out:
# temperatur -> 100 Smoke -> 50
# Smoke and temperature is greater than 50
# ALARAM SOUND ON.......
#
#
#
# CALLING THE FIRE DEPT...........................
# SPRINLE SYSTEM ACTIVATED..................
#  state smoke and High Temp

# %% [markdown]
# pre processing and other thing

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.over_sampling import SMOTE

# Step 1: Data Cleaning
def handle_missing_values(data):
    # Fill missing values with mean
    data.fillna(data.mean(), inplace=True)
    return data

def remove_outliers(data, threshold=3):
    # Remove outliers using z-score
    z_scores = (data - data.mean()) / data.std()
    data = data[(z_scores < threshold).all(axis=1)]
    return data

# Step 2: Data Integration
def integrate_data(data1, data2):
    # Merge the two datasets based on a common key or index
    merged_data = pd.merge(data1, data2, on='common_key')
    return merged_data

# Step 3: Data Transformation
def normalize_data(data):
    # Perform feature-wise normalization
    scaler = StandardScaler()
    normalized_data = scaler.fit_transform(data)
    return normalized_data

# Step 4: Feature Selection
def select_features(X, y, k=10):
    # Perform feature selection using ANOVA F-value
    selector = SelectKBest(f_classif, k=k)
    X_new = selector.fit_transform(X, y)
    return X_new

# Step 5: Feature Encoding
def encode_features(data):
    # Perform feature encoding for categorical variables
    encoder = LabelEncoder()
    encoded_data = data.copy()
    for column in data.columns:
        if data[column].dtype == 'object':
            encoded_data[column] = encoder.fit_transform(data[column])
    return encoded_data

# Step 6: Data Splitting
def split_data(X, y, test_size=0.2, random_state=42):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

# Step 7: Handling Imbalanced Data
def handle_imbalanced_data(X, y):
    # Perform oversampling using SMOTE
    oversampler = SMOTE()
    X_resampled, y_resampled = oversampler.fit_resample(X, y)
    return X_resampled, y_resampled

# Step 8: Dimensionality Reduction (if applicable)
def reduce_dimensionality(data, n_components=2):
    # Perform PCA for dimensionality reduction
    pca = PCA(n_components=n_components)
    reduced_data = pca.fit_transform(data)
    return reduced_data

# Step 9: Correlation Analysis
def analyze_correlation(data):
    correlation_matrix = data.corr()
    # Perform correlation analysis, e.g., visualize correlation matrix, identify highly correlated features, etc.
    # You can use seaborn, matplotlib, or any other library for visualization and analysis

# Example usage
# Assuming you have two pandas DataFrames 'df1' and 'df2' with input data and a common key 'common_key'
# Step 1: Data Cleaning
cleaned_data1 = handle_missing_values(df1)
cleaned_data1 = remove_outliers(cleaned_data1)

cleaned_data2 = handle_missing_values(df2)
cleaned_data2 = remove_outliers(cleaned_data2)

# Step 2: Data Integration
merged_data = integrate_data(cleaned_data1, cleaned_data2)

# Step 3: Data Transformation
normalized_data = normalize_data(merged_data)
#Step 4: Feature Selection

X = normalized_data.drop('target', axis=1)
y = normalized_data['target']
X_selected = select_features(X, y, k=10)
#Step 5: Feature Encoding

encoded_data = encode_features(X_selected)
#Step 6: Data Splitting

X_train, X_test, y_train, y_test = split_data(encoded_data, y)
#Step 7: Handling Imbalanced Data

X_train_resampled, y_train_resampled = handle_imbalanced_data(X_train, y_train)
#Step 8: Dimensionality Reduction

reduced_train_data = reduce_dimensionality(X_train_resampled)
reduced_test_data = reduce_dimensionality(X_test)
#Step 9: Correlation Analysis

analyze_correlation(merged_data)

# %% [markdown]
# knn

# %%
#libs
# Modeling imports
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, confusion_matrix, classification_report

# %%
## Generating Synthetic Data for a Binary Classification Problem
np.random.seed(0)

good_data = np.random.randint(low=3, high=7, size=(25, 2)) * np.random.normal(loc=1, scale=0.5, size=(25, 2))
bad_data = np.random.randint(low=0, high=3, size=(25, 2)) * np.random.normal(loc=1, scale=0.5, size=(25, 2))

df = pd.DataFrame({'X1': np.concatenate([good_data[:, 0], bad_data[:, 0]]),
                   'X2': np.concatenate([good_data[:, 1], bad_data[:, 1]]),
                   'Y': np.concatenate([['Good'] * 25, ['Bad'] * 25])})

df = df.sample(frac=1).reset_index(drop=True)
df.head()
df.info()
df.describe()

# %% [markdown]
# train test model

# %%
X = df[['X1', 'X2']]
y = df['Y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# knn by lib

# %%
knn = KNeighborsClassifier(n_neighbors=5)
# Train the model using the fit method
knn.fit(X_train, y_train)
y_pred= knn.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
#predict new data labels
new_data = pd.DataFrame({'X1': [6,1,3], 'X2': [5,2,3]})

new_label = knn.predict(new_data)
print("Predicted Label for New Data:", new_label)
print(confusion_matrix(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 knn = KNeighborsClassifier(n_neighbors=5)
#       2 # Train the model using the fit method
# ----> 3 knn.fit(X_train, y_train)
#       4 y_pred= knn.predict(X_test)
#       5 y_pred
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# knn by user

# %%
class knn:
    def __init__(self):
        import pandas as pd
        import numpy as np

    def read_file(self, filename):
        data = pd.read_csv(filename)
        dataframe = pd.DataFrame(data)
        return dataframe

    def remove_unused_data(self, filename):
        datafame = filename.replace(np.nan,0)
        return datafame

    def __str__(self):
        return self.data

    def generate_data(self,data):
        data = data.loc[:,:]
        return data

    def calculate_distance(self,point1,point2):
        distance = 0
        for i in range(len(point1)):
            distance += (point1[i] - point2[i])**2
        return distance**0.5    

    def calculate_neighbors(self,train_data, train_labels, test_instance, k):
        distances = []
        for i in range(len(train_data)):
            dist = self.calculate_distance(test_instance, train_data[i])
            distances.append((train_data[i], dist, train_labels[i]))
        distances.sort(key=lambda x: x[1])
        neighbors = distances[:k]
        class_votes = {}
        for i in range(k):
            response = neighbors[i][2]
            if response in class_votes:
                class_votes[response] += 1
            else:
                class_votes[response] = 1
        sorted_votes = sorted(class_votes.items(), key=lambda x: x[1], reverse=True)
        return sorted_votes[0][0]

# %% [markdown]
# Decision tree

# %% [markdown]
# dts by libs

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

# %% [markdown]
# entropy

# %%
DTC_Model =DecisionTreeClassifier(criterion= 'entropy', max_depth=4, random_state=10)

DTC_Model.fit(x_train, y_train)
DTC_Model.score(x_train , y_train)
y_pred = DTC_Model.predict(x_test)
print(y_pred)

# now print the actual labels
print(y_test)

DTC_Model.score(x_test , y_test)

# %% [markdown]
# gini

# %% [markdown]
# DTC_gini =DecisionTreeClassifier(criterion= 'gini', max_depth=4, random_state=10)
#
# DTC_gini.fit(x_train, y_train)
# DTC_gini.score(x_train , y_train)
# y_pred = DTC_gini.predict(x_test)
# accuracy_gini=DTC_gini.score(x_test , y_test)
# print(accuracy_gini)

# %% [markdown]
# getting important features

# %%
feature_importances_entropy = DTC_Model.feature_importances_
feature_importances_gini = DTC_gini.feature_importances_

print("the entropy criterion:", feature_importances_entropy)
print("the gini criterion:", feature_importances_gini)

# %% [markdown]
# decision tree without lib

# %%
import numpy as np

class DecisionTree:
    def __init__(self):
        self.tree = None

    def _calculate_gini_index(self, y):
        classes = np.unique(y)
        gini = 0
        total_samples = len(y)

        for cls in classes:
            p = len(y[y == cls]) / total_samples
            gini += p * (1 - p)

        return gini

    def _split_dataset(self, X, y, feature_index, threshold):
        left_mask = X[:, feature_index] <= threshold
        right_mask = X[:, feature_index] > threshold

        X_left = X[left_mask]
        y_left = y[left_mask]

        X_right = X[right_mask]
        y_right = y[right_mask]

        return X_left, y_left, X_right, y_right

    def _find_best_split(self, X, y):
        best_gini = np.inf
        best_feature_index = None
        best_threshold = None

        for feature_index in range(X.shape[1]):
            unique_values = np.unique(X[:, feature_index])

            for value in unique_values:
                X_left, y_left, X_right, y_right = self._split_dataset(X, y, feature_index, value)
                gini_left = self._calculate_gini_index(y_left)
                gini_right = self._calculate_gini_index(y_right)
                gini = (len(y_left) / len(y)) * gini_left + (len(y_right) / len(y)) * gini_right

                if gini < best_gini:
                    best_gini = gini
                    best_feature_index = feature_index
                    best_threshold = value

        return best_feature_index, best_threshold

    def _build_tree(self, X, y):
        if len(np.unique(y)) == 1:
            # If all samples belong to the same class, create a leaf node
            return {'class': y[0]}

        best_feature_index, best_threshold = self._find_best_split(X, y)

        X_left, y_left, X_right, y_right = self._split_dataset(X, y, best_feature_index, best_threshold)

        # Recursively build the left and right subtrees
        left_subtree = self._build_tree(X_left, y_left)
        right_subtree = self._build_tree(X_right, y_right)

        # Create a node with the best feature index and threshold
        node = {
            'feature_index': best_feature_index,
            'threshold': best_threshold,
            'left': left_subtree,
            'right': right_subtree
        }

        return node

    def fit(self, X, y):
        self.tree = self._build_tree(X, y)

    def _predict_sample(self, sample, node):
        if 'class' in node:
            return node['class']

        if sample[node['feature_index']] <= node['threshold']:
            return self._predict_sample(sample, node['left'])
        else:
            return self._predict_sample(sample, node['right'])

    def predict(self, X):
        predictions = []

        for sample in X:
            prediction = self._predict_sample(sample, self.tree)
            predictions.append(prediction)

        return np.array(predictions)
X_train = np.array([[2.0, 1.0], [1.0, 5.0], [4.

0, 2.0], [3.0, 4.0]])
y_train = np.array([0, 0, 1, 1])

dt = DecisionTree()
dt.fit(X_train, y_train)

X_test = np.array([[2.5, 3.0], [1.5, 1.5]])
predictions = dt.predict(X_test)
print(predictions)

# %% [markdown]
# plot tree

# %%
# DTC_tree = tree.plot_tree(DTC_Model)
plt.figure(figsize=(10, 9))

DTC_tree = tree.plot_tree(DTC_Model, filled=True, 
                          feature_names=['sepal length', 'sepal width', 'petal length', 'petal width'],
                          fontsize=10,  
                          )

# %% [markdown]
# ANN

# %% [markdown]
# lib

# %%
from sklearn.linear_model import Perceptron

# %% [markdown]
# ann without lib

# %%
#predict with weights
def predict(row, weights):
    activation = weights[0]
    for i in range(len(row)-1):
        activation += weights[i + 1] * row[i]
    return 1.0 if activation >= 0.0 else 0.0

weights = [-0.1, 0.20653640140000007, -0.23418117710000003]
for row in dataset:
    prediction = predict(row, weights)
    print("Expected=%d, Predicted=%d" % (row[-1], prediction))

# %%
#train weight
def train_weights(train, l_rate, n_epoch):
    
    weights = [0.0 for i in range(len(train[0]))]
    
    for epoch in range(n_epoch):
        
        sum_error = 0.0
        
        for row in train:
            
            prediction = predict(row, weights)
            
            error = row[-1] - prediction
            
            sum_error += error**2
            
            weights[0] = weights[0] + l_rate * error  #bias(t+1) = bias(t) + learning_rate * (expected(t) - predicted(t))
            
            for i in range(len(row)-1):
                
                weights[i + 1] = weights[i + 1] + l_rate * error * row[i] #w(t+1) = w(t) + learning_rate * (expected(t) - predicted(t)) * x(t)
                
        print('epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        
    return weights

# %%
l_rate = 0.1
n_epoch = 5
weights = train_weights(dataset, l_rate, n_epoch)
print(weights)

# %%
import numpy as np

class NeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # Initialize weights and biases randomly
        self.W1 = np.random.randn(self.input_size, self.hidden_size)
        self.b1 = np.zeros((1, self.hidden_size))
        self.W2 = np.random.randn(self.hidden_size, self.output_size)
        self.b2 = np.zeros((1, self.output_size))

    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def _sigmoid_derivative(self, x):
        return self._sigmoid(x) * (1 - self._sigmoid(x))

    def forward(self, X):
        # Perform forward propagation
        self.z1 = np.dot(X, self.W1) + self.b1
        self.a1 = self._sigmoid(self.z1)
        self.z2 = np.dot(self.a1, self.W2) + self.b2
        self.a2 = self._sigmoid(self.z2)
        return self.a2

    def backward(self, X, y, output):
        # Perform backward propagation and update weights/biases
        self.dz2 = output - y
        self.dW2 = np.dot(self.a1.T, self.dz2)
        self.db2 = np.sum(self.dz2, axis=0, keepdims=True)
        self.dz1 = np.dot(self.dz2, self.W2.T) * self._sigmoid_derivative(self.z1)
        self.dW1 = np.dot(X.T, self.dz1)
        self.db1 = np.sum(self.dz1, axis=0, keepdims=True)

        # Update weights and biases
        self.W1 -= learning_rate * self.dW1
        self.b1 -= learning_rate * self.db1
        self.W2 -= learning_rate * self.dW2
        self.b2 -= learning_rate * self.db2

    def train(self, X, y, epochs, learning_rate):
        for epoch in range(epochs):
            # Forward propagation
            output = self.forward(X)

            # Backward propagation and weight updates
            self.backward(X, y, output)

    def predict(self, X):
        # Perform forward propagation to get predictions
        output = self.forward(X)
        # Threshold the output (assuming binary classification)
        predictions = (output >= 0.5).astype(int)
        return predictions
# Example usage
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# Create an instance of the NeuralNetwork class
input_size = X.shape[1]
hidden_size = 4
output_size = y.shape[1]
nn = NeuralNetwork(input_size, hidden_size, output_size)

# Train the neural network
epochs = 10000
learning_rate = 0.1
nn.train(X, y, epochs, learning_rate)

# Make predictions
predictions = nn.predict(X)
print(predictions)

# %% [markdown]
# with lib

# %%
perceptron = Perceptron()
perceptron.fit(X_train, y_train)
y_pred = perceptron.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# %% [markdown]
# MLP

# %% [markdown]
# Lib

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification

# %% [markdown]
# with lib

# %%
mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(8,6), max_iter=300, random_state=1)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('F1 score:', f1_score(y_test, y_pred))

# %% [markdown]
# without lib

# %%
import numpy as np

class MLP:
    def __init__(self, num_inputs, num_hidden, num_outputs):
        self.num_inputs = num_inputs
        self.num_hidden = num_hidden
        self.num_outputs = num_outputs
        
        self.W1 = np.random.randn(self.num_inputs, self.num_hidden)
        self.b1 = np.zeros((1, self.num_hidden))
        self.W2 = np.random.randn(self.num_hidden, self.num_outputs)
        self.b2 = np.zeros((1, self.num_outputs))
        
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_derivative(self, x):
        return x * (1 - x)
    
    def feedforward(self, X):
        self.z1 = np.dot(X, self.W1) + self.b1
        self.a1 = self.sigmoid(self.z1)
        self.z2 = np.dot(self.a1, self.W2) + self.b2
        self.a2 = self.sigmoid(self.z2)
        return self.a2
    
    def backpropagation(self, X, y, output):
        error_output = y - output
        delta_output = error_output * self.sigmoid_derivative(output)
        
        error_hidden = delta_output.dot(self.W2.T)
        delta_hidden = error_hidden * self.sigmoid_derivative(self.a1)
        
        self.W2 += self.a1.T.dot(delta_output)
        self.b2 += np.sum(delta_output, axis=0, keepdims=True)
        self.W1 += X.T.dot(delta_hidden)
        self.b1 += np.sum(delta_hidden, axis=0)
    
    def train(self, X, y, num_epochs, learning_rate):
        for i in range(num_epochs):
            output = self.feedforward(X)
            self.backpropagation(X, y, output)
            
    def predict(self, X):
        return self.feedforward(X)
# create an MLP with 2 inputs, 2 hidden neurons, and 1 output
mlp = MLP(2, 2, 1)

# train the MLP on some input/output pairs
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])
mlp.train(X, y, num_epochs=10000, learning_rate=0.1)

# make predictions on some new inputs
X_test = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
predictions = mlp.predict(X_test)
print(predictions)

# %% [markdown]
# kmean

# %% [markdown]
# lib

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# with lib

# %%
SSE = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_selected)
    SSE.append(kmeans.inertia_)

# %%
means = KMeans(n_clusters=4, random_state=42)
kmeans.fit(data_selected)

# %% [markdown]
# without lib

# %%
import numpy as np

class KMeans:
    def __init__(self, num_clusters):
        self.num_clusters = num_clusters
        self.centroids = None
    
    def initialize_centroids(self, X):
        random_indices = np.random.choice(X.shape[0], size=self.num_clusters, replace=False)
        self.centroids = X[random_indices]
    
    def assign_clusters(self, X):
        distances = np.sqrt(((X[:, np.newaxis] - self.centroids) ** 2).sum(axis=2))
        return np.argmin(distances, axis=1)
    
    def update_centroids(self, X, labels):
        self.centroids = np.array([X[labels == k].mean(axis=0) for k in range(self.num_clusters)])
    
    def fit(self, X, max_iterations=100):
        self.initialize_centroids(X)
        
        for _ in range(max_iterations):
            prev_centroids = self.centroids.copy()
            
            labels = self.assign_clusters(X)
            self.update_centroids(X, labels)
            
            if np.allclose(prev_centroids, self.centroids):
                break
    
    def predict(self, X):
        labels = self.assign_clusters(X)
        return labels
# create a KMeans instance with 3 clusters
kmeans = KMeans(num_clusters=3)

# generate some sample data
np.random.seed(42)
X = np.random.randn(100, 2)

# fit the KMeans model to the data
kmeans.fit(X)

# make predictions on new data points
X_new = np.random.randn(10, 2)
predictions = kmeans.predict(X_new)
print(predictions)

# %% [markdown]
# BFS

# %%
import networkx as nx
import matplotlib.pyplot as plt
edges = [("Arad", "Zerind", 75),("Arad", "Sibiu", 140),("Arad", "Timisoara", 118),("Bucharest", "Fagaras", 211),
         ("Oradea","Zerind",71),("Oradea","Sibiu",151),
         ("Zerind","Arad",75),
         ('Timisoara','Arad',118),('Timisoara','Lugoj',111),
         ('Lugoj','Timisoara',111),("Lugoj","Mehadia",70),
         ("Mehadia",'Lugoj',70),('Mehadia','Dobreta',75),
         ('Dobreta','Mehadia',75),('Dobreta','Craiova',120),
         ('Craiova','Dobreta',120),('Craiova','Pitesti',138),('Craiova','Rimnicu Vilcea',146),
         ('Rimnicu Vilcea','Craiova',146),('Rimnicu Vilcea','Sibiu',80),('Rimnicu Vilcea','Pitesti',97),
         ('Pitesti','Craiova',138),('Pitesti','Rimnicu Vilcea',97),('Pitesti','Bucharest',101),
         ('Sibiu','Arad',140),('Sibiu','Oradea',151),('Sibiu','Fagaras',99),
         ('Bucharest','Giurgiu',90),('Bucharest','Pitesti',101),('Bucharest','Fagaras',211),('Bucharest','Urziceni',85),
         ('Giurgiu','Bucharest',90),
         ('Fagaras','Sibiu',99),('Fagaras','Bucharest',211),
         ('Urziceni','Bucharest',85),('Urziceni','Hirsova',98),('Urziceni','Vaslui',142),
         ('Hirsova','Urziceni',98),('Hirsova','Eforie',86),
         ('Eforie','Hirsova',86),
         ('Vaslui','Urziceni',142),('Vaslui','Lasi',92),
         ('Lasi','Vaslui',92),('Lasi','Neamt',87),
         ('Neamt','Lasi',87)
         
         ] #add remaining edges to the list

for edge in edges:
    G.add_edge(edge[0], edge[1], weight=edge[2])
# Set node positions using Kamada-Kawai layout
pos = nx.kamada_kawai_layout(G)
# Draw graph with labels and edge weights
plt.figure(figsize=(18, 10))
nx.draw(G, pos, with_labels=True, font_size=12, node_size= 1500, node_color ="yellow")

edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)

plt.show()

class Node():
    def __init__(self, state, parent, action):
        self.state = state
        self.parent = parent
        self.action = action
        
        
class StackFrontier():
    def __init__(self):
        self.frontier = []

    def add(self, node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any(node.state == state for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def remove(self):
        if self.empty():
            raise Exception("empty frontier")
        else:
            node = self.frontier[-1]
            self.frontier = self.frontier[:-1]
            return node
class QueueFrontier(StackFrontier):

    def remove(self):
        if self.empty():
            raise Exception("empty frontier")
        else:
            node = self.frontier[0]
            self.frontier = self.frontier[1:]
            return node

# %% [markdown]
# without lib

# %%
def bfs_search(graph, start, goal):
    """Perform breadth-first search from start to goal."""
    
    
    #your code 
    start_node = Node(state=start, parent=None, action=None)
    
    frontier = QueueFrontier()

        
    frontier.add(start_node)
    explored = set()
    
    while True:
        if frontier.empty():
            return None
        
        node = frontier.remove()
        explored.add(node.state)
        
        if node.state == goal:
            actions = []
            states = []
            while node.parent is not None:
                actions.append('{weight:' + str(node.action)+ '}')
                states.append(node.state)
                node = node.parent
            actions.reverse()
            states.reverse()
            return (actions, states)

        for neighbor in graph.neighbors(node.state):
            if neighbor not in explored and not frontier.contains_state(neighbor):
                child_node = Node(state=neighbor, parent=node, action=graph.edges[(node.state, neighbor)]['weight'])
                frontier.add(child_node)

# %% [markdown]
# with lib

# %%
import queue

class Node:
    def __init__(self, state, parent, action):
        self.state = state
        self.parent = parent
        self.action = action

def bfs_search(graph, start, goal):
    """Perform breadth-first search from start to goal."""
    
    start_node = Node(state=start, parent=None, action=None)
    
    frontier = queue.Queue()
    frontier.put(start_node)
    
    explored = set()
    
    while not frontier.empty():
        node = frontier.get()
        explored.add(node.state)
        
        if node.state == goal:
            actions = []
            states = []
            while node.parent is not None:
                actions.append(graph.edges[(node.parent.state, node.state)]['weight'])
                states.append(node.state)
                node = node.parent
            actions.reverse()
            states.reverse()
            return (actions, states)
        
        for neighbor in graph.neighbors(node.state):
            if neighbor not in explored:
                child_node = Node(state=neighbor, parent=node, action=graph.edges[(node.state, neighbor)]['weight'])
                frontier.put(child_node)
    
    return None

# %% [markdown]
# dfs

# %% [markdown]
# without lib

# %%
def dfs_search(graph, start, goal):
    """Perform depth-first search from start to goal."""
    
    #your code
    start_node = Node(state=start, parent=None, action=None)
    
    frontier = StackFrontier()

        
    frontier.add(start_node)
    explored = set()
    
    while True:
        if frontier.empty():
            return None
        
        node = frontier.remove()
        explored.add(node.state)
        
        if node.state == goal:
            actions = []
            states = []
            while node.parent is not None:
                actions.append('{weight:' + str(node.action)+ '}')
                states.append(node.state)
                node = node.parent
            actions.reverse()
            states.reverse()
            return (actions, states)

        for neighbor in graph.neighbors(node.state):
            if neighbor not in explored and not frontier.contains_state(neighbor):
                child_node = Node(state=neighbor, parent=node, action=graph.edges[(node.state, neighbor)]['weight'])
                frontier.add(child_node)

# %% [markdown]
# with lib

# %%
from collections import deque

class Node:
    def __init__(self, state, parent, action):
        self.state = state
        self.parent = parent
        self.action = action

def bfs_search(graph, start, goal):
    """Perform breadth-first search from start to goal."""
    
    start_node = Node(state=start, parent=None, action=None)
    
    frontier = deque()
    frontier.append(start_node)
    
    explored = set()
    
    while frontier:
        node = frontier.popleft()
        explored.add(node.state)
        
        if node.state == goal:
            actions = []
            states = []
            while node.parent is not None:
                actions.append(graph.edges[(node.parent.state, node.state)]['weight'])
                states.append(node.state)
                node = node.parent
            actions.reverse()
            states.reverse()
            return (actions, states)
        
        for neighbor in graph.neighbors(node.state):
            if neighbor not in explored:
                child_node = Node(state=neighbor, parent=node, action=graph.edges[(node.state, neighbor)]['weight'])
                frontier.append(child_node)
    
    return None

# %% [markdown]
# hill climber

# %% [markdown]
# 8 queen

# %%
import random
import numpy as np
def make_board(size):
    board = np.zeros((size,size))    
    return(board)
    
def place_queen(size):
    board = make_board(size)
    for i in range(size):
        board[i][random.randint(0,size-1)] = 1
    
    return board
def object_function(board):
    attack = 0
    length_board = len(board)
    
    for row in range(length_board):
        for col in range(length_board):
            if board[row][col] == 1:
                for i in range(col+1,length_board):
                    if board[row][i] == 1:
                        attack+=1
                for i, j in zip(range(row-1, -1, -1), range(col+1, length_board)):
                    if board[i][j] == 1:
                        attack += 1
                for i, j in zip(range(row+1, length_board), range(col+1, length_board)):
                    if board[i][j] == 1:
                        attack += 1
        
    
    return (attack)
def generate_neighbors(board):
    neighbors = []
    len_board = len(board)
    
    for col in range(len_board):
        row = np.argmax(board[:,col])
        for i in range(len_board):
            if i != row:
                new_board = np.copy(board)
                new_board[row][col] = 0
                new_board[i][col] = 1
                neighbors.append(new_board)
    return neighbors
def hill_climbing(size):
    board = make_board(size)
    board = place_queen(size)
    h_current = object_function(board)

    while True:
        neighbors = generate_neighbors(board)
        h_neighbors = [object_function(neighbor) for neighbor in neighbors]

        min_h_neighbor = min(h_neighbors)
        
        print('min_h_neighbor -> ' + str(min_h_neighbor))
        print('h_current -> ' + str(h_current))
        
        
        if min_h_neighbor >= h_current:
            return board, h_current

        best_neighbors = [neighbors[i] for i, h in enumerate(h_neighbors) if h == min_h_neighbor]
        board = random.choice(best_neighbors)
        h_current = min_h_neighbor
    

n = 8
attempts = 100
successes = 0

for i in range(attempts):
    solution, h = hill_climbing(n)
    if h == 0:
        successes += 1

success_rate = (successes / attempts) * 100
print(f"Success rate for N = {n}: {success_rate}%")

# %% [markdown]
# best first search

# %%
import networkx as nx
import matplotlib.pyplot as plt
from queue import PriorityQueue
class Node:
    def __init__(self, name, cost, heuristic, parent):
        self.name = name
        self.cost = cost
        self.heuristic = heuristic
        self.parent = parent

    def __lt__(self, other):
        return (self.cost + self.heuristic) < (other.cost + other.heuristic)
G = nx.Graph()

G.add_nodes_from(["Arad", "Bucharest","Oradea","Zerind","Sibiu","Timisoara","Lugoj","Mehadia","Dobreta","Craiova","Pitesti","Rimnicu Vilcea","Fagaras","Bucharest","Giurgiu","Uriceni","Hirsova","Eforie","Vaslui","Lasi","Neamt"])
edges = [("Arad", "Zerind", 75),("Arad", "Sibiu", 140),("Arad", "Timisoara", 118),("Bucharest", "Fagaras", 211),
         ("Oradea","Zerind",71),("Oradea","Sibiu",151),
         ("Zerind","Arad",75),
         ('Timisoara','Arad',118),('Timisoara','Lugoj',111),
         ('Lugoj','Timisoara',111),("Lugoj","Mehadia",70),
         ("Mehadia",'Lugoj',70),('Mehadia','Dobreta',75),
         ('Dobreta','Mehadia',75),('Dobreta','Craiova',120),
         ('Craiova','Dobreta',120),('Craiova','Pitesti',138),('Craiova','Rimnicu Vilcea',146),
         ('Rimnicu Vilcea','Craiova',146),('Rimnicu Vilcea','Sibiu',80),('Rimnicu Vilcea','Pitesti',97),
         ('Pitesti','Craiova',138),('Pitesti','Rimnicu Vilcea',97),('Pitesti','Bucharest',101),
         ('Sibiu','Arad',140),('Sibiu','Oradea',151),('Sibiu','Fagaras',99),
         ('Bucharest','Giurgiu',90),('Bucharest','Pitesti',101),('Bucharest','Fagaras',211),('Bucharest','Urziceni',85),
         ('Giurgiu','Bucharest',90),
         ('Fagaras','Sibiu',99),('Fagaras','Bucharest',211),
         ('Urziceni','Bucharest',85),('Urziceni','Hirsova',98),('Urziceni','Vaslui',142),
         ('Hirsova','Urziceni',98),('Hirsova','Eforie',86),
         ('Eforie','Hirsova',86),
         ('Vaslui','Urziceni',142),('Vaslui','Lasi',92),
         ('Lasi','Vaslui',92),('Lasi','Neamt',87),
         ('Neamt','Lasi',87)
         
         ] #add remaining edges to the list

for edge in edges:
    G.add_edge(edge[0], edge[1], weight=edge[2])
# Set node positions using Kamada-Kawai layout
pos = nx.kamada_kawai_layout(G)
# Draw graph with labels and edge weights
plt.figure(figsize=(18, 10))
nx.draw(G, pos, with_labels=True, font_size=12, node_size= 1500, node_color ="yellow")

edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)

plt.show()

romina_edges={}
for edge in edges:
    if edge[0] not in romina_edges:
        romina_edges[edge[0]] = []
    romina_edges[edge[0]].append((edge[1], edge[2]))
print(romina_edges)


heuristic_values = {
    "Arad": 366,
    "Bucharest": 0,
    "Craiova": 160,
    "Dobreta": 242,
    "Eforie": 161,
    "Fagaras": 176,
    "Giurgiu": 77,
    "Hirsova": 151,
    "Iasi": 226,
    "Lugoj": 244,
    "Mehadia": 241,
    "Neamt": 234,
    "Oradea": 380,
    "Pitesti": 100,
    "Rimnicu Vilcea": 193,
    "Sibiu": 253,
    "Timisoara": 329,
    "Urziceni": 80,
    "Vaslui": 199,
    "Zerind": 374
}

def best_first_search(starting,goal):
    PQ = PriorityQueue()

    visited = []
    closed = []

    PQ.put((heuristic_values[starting],starting))

    while PQ.empty() == False:
        
        n = PQ.get()
        
        h = n[0]
        city = n[1]
        
        closed.append(city)
        visited.append(city)
        
        successors = [i for i in G.neighbors( city)]
        
        if goal in successors:
            
            visited.append(goal)
            cost = nx.path_weight(G, visited, "weight")
            print("Goal city:", goal, "reached.")
            print("Visited cities:", visited)
            print("Cost = ", cost)
            break
            
        successor_queue = PriorityQueue()
        
        for i in successors:
            successor_queue.put((heuristic_values[i], i))
        
        for i in successors:
            s = successor_queue.get()
            if s not in closed and s not in visited:
                PQ.put(s)
                break

# %% [markdown]
# A*

# %%
class Node:
    def __init__(self, name, cost, heuristic, parent):
        self.name = name
        self.cost = cost
        self.heuristic = heuristic
        self.parent = parent
        self.f = cost + heuristic

    def __lt__(self, other):
        return self.f < other.f

#all code from above
def a_star_search(starting, goal):
    PQ = PriorityQueue()
    PQ.put((0 + heuristic_values[starting], starting, 0))

    visited = set()

    while not PQ.empty():
        _, city, cost = PQ.get()
        visited.add(city)

        if city == goal:
            print("Goal city:", goal, "reached.")
            print("Visited cities:", visited)
            print("Cost = ", cost)
            return

        for successor in G.neighbors(city):
            if successor not in visited:
                successor_cost = cost + G[city][successor]['weight']
                PQ.put((successor_cost + heuristic_values[successor], successor, successor_cost))

    print("Goal city:", goal, "cannot be reached from starting city:", starting)

# %% [markdown]
# genetic algo

# %% [markdown]
# without lib

# %%
import numpy as np
import random

POPULATION_SIZE = 16
MUTATION_RATE = 0.01
start = np.zeros((4, 4))
goal = np.ones((4,4))
initial_chromosome = start.reshape(16)
def fitness_function(state):
    return np.count_nonzero(state == 1)
def selection(population, fitnesses):
    fitnesses = np.array(fitnesses) + 1e-6
    total_fitness = sum(fitnesses)
    selection_probabilities = [fitness / total_fitness for fitness in fitnesses]
    selection_probabilities = [prob / sum(selection_probabilities) for prob in selection_probabilities]
    parents_indices = np.random.choice(len(population), size=2, replace=False, p=selection_probabilities)
    parents = [population[i] for i in parents_indices]
    return parents
def crossover(parents):
    crossover_point = random.randint(0, len(parents[0]))
    child1 = np.concatenate((parents[0][:crossover_point], parents[1][crossover_point:]))
    child2 = np.concatenate((parents[1][:crossover_point], parents[0][crossover_point:]))
    return [child1, child2]
def mutation(children, mutation_rate):
    for i in range(len(children)):
        for j in range(len(children[i])):
            if np.random.rand() < mutation_rate:
                children[i][j] = 1 - children[i][j]
    return children
def genetic_algorithm(population, max_iterations, mutation_rate):
    iteration = 0

    while iteration < max_iterations:
        fitnesses = [fitness_function(chromosome) for chromosome in population]

        if np.max(fitnesses) == len(initial_chromosome):
            return population[np.argmax(fitnesses)]

        parents = selection(population, fitnesses)

        children = crossover(parents)

        children = mutation(children, mutation_rate)

        children_fitness = [fitness_function(child) for child in children]


        if np.max(children_fitness) == len(initial_chromosome):
            return children[np.argmax(children_fitness)]

        worst_fitness_indices = np.argsort(fitnesses)[:len(children)]
        for i, child in enumerate(children):
            population[worst_fitness_indices[i]] = child

        iteration += 1

    return population[np.argmax(fitnesses)]
population_size = 20
population = [initial_chromosome for i in range(population_size)]
max_iterations = 1000
mutation_rate = 0.01
solution = genetic_algorithm(population, max_iterations, mutation_rate)

solution

# %% [markdown]
# with lib

# %%
import numpy as np
import random
from deap import creator, base, tools, algorithms

POPULATION_SIZE = 16
MUTATION_RATE = 0.01
start = np.zeros((4, 4))
goal = np.ones((4, 4))
initial_chromosome = start.reshape(16)

def fitness_function(state):
    return np.count_nonzero(state == 1)

def crossover(parent1, parent2):
    crossover_point = random.randint(0, len(parent1))
    child1 = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))
    child2 = np.concatenate((parent2[:crossover_point], parent1[crossover_point:]))
    return child1, child2

def mutation(individual):
    for i in range(len(individual)):
        if np.random.rand() < MUTATION_RATE:
            individual[i] = 1 - individual[i]
    return individual,

creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", np.ndarray, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("individual", tools.initRepeat, creator.Individual, random.randint(0, 1), len(initial_chromosome))
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", fitness_function)
toolbox.register("mate", crossover)
toolbox.register("mutate", mutation)
toolbox.register("select", tools.selTournament, tournsize=3)

def genetic_algorithm(population, max_iterations):
    iteration = 0

    while iteration < max_iterations:
        offspring = algorithms.varAnd(population, toolbox, cxpb=0.5, mutpb=0.1)
        fits = toolbox.map(toolbox.evaluate, offspring)

        for fit, ind in zip(fits, offspring):
            ind.fitness.values = (fit,)

        if np.max(fits) == len(initial_chromosome):
            return offspring[np.argmax(fits)]

        population = toolbox.select(offspring, k=len(population))

        iteration += 1

    return population[np.argmax([ind.fitness.values[0] for ind in population])]

population_size = 20
population = toolbox.population(n=population_size)
max_iterations = 1000
solution = genetic_algorithm(population, max_iterations)

best_individual = max(solution, key=lambda ind: ind.fitness.values[0])
best_solution = np.array(best_individual)

best_solution
